# %% [markdown]
# # Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot() # create empty plot
# Out:
# []

# %%
plt.plot(); # create empty plot without "[]"

# %%
plt.plot([1,2,3,4]);

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y);

# %% [markdown]
# #### Use object oriented method for using plots as it is more efficient.

# %%
# 1st method,
fig = plt.figure() #creates a figure
ax = fig.add_subplot() #adds axes
plt.show()

# %%
# kind of a long version of doing
plt.plot()
# Out:
# []

# %%
# 2nd method
fig = plt.figure() #creates a figure
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x,y)
plt.show()

# %%
# 3rd method (recommended)
fig, ax = plt.subplots()
ax.plot(x,y); #adds data to x and y
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ## Workflow

# %%
# Import Matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# Prepare data
x = [1,2,3,4,5]
y = [2,4,6,8,10]

# Setup plot
fig, ax = plt.subplots(figsize = (10,10)) # dimensions of the plot

# Plot data
ax.plot(x, y)

# Customize plot
ax.set(title = "Simple plot", xlabel = "x-axis", ylabel = "y-axis")

# Save figure
fig.savefig("sample_plot.png")

# %% [markdown]
# ## Making figures with NumPy arrays

# %%
# create some data
x = np.linspace(0, 10, 100) # creates a list of 100 evenly spaced no from 0 to 10
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# plot data
fig, ax = plt.subplots()
ax.plot(x,x**2);
# by default it is a line plot

# %%
# make a scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
# again a scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# make a plot from dictionary - a bar graph
sales = {"Android": 100,
          "iOS": 200,
          "Windows": 150}
fig, ax = plt.subplots()
ax.bar(sales.keys(), sales.values());
ax.set(title = "Shop sales",
       ylabel = "No of units sold");

# %%
fig, ax = plt.subplots()
ax.barh(list(sales.keys()), list(sales.values())); #horizontal bar, requires list

# %%
x = np.random.randn(1000) #creates a random normal distribtion
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Different methods for creating subplots

# %%
# method 1
fig, ((ax1,ax2), (ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,5))

#plot to each axes
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(sales.keys(), sales.values());
ax4.hist(np.random.randn(1000));

# %%
# method 2
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,5))

# plot to different indices
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10), np.random.random(10));
ax[1,0].bar(sales.keys(), sales.values());
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from pandas DataFrames

# %%
# make a dataframes
carSales = pd.read_csv("data/car-sales.csv")
carSales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000), index = pd.date_range("1/1/2020", periods = 1000))
ts = ts.cumsum()
ts.plot()

# %%
carSales["Price"] = carSales["Price"].str.replace('[\$\,\.]','')
carSales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# Remove last two zeroes
carSales["Price"] = carSales["Price"].str[:-2]
carSales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
carSales["Sale Date"] = pd.date_range("1/1/2020", periods = len(carSales))

# %%
carSales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
carSales["Total Sales"] = carSales["Price"].astype(int).cumsum()

# %%
carSales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
#plotting the total sales
carSales.plot(x="Sale Date", y="Total Sales");

# %%
carSales["Price"] = carSales["Price"].astype(int) # reassign price column as int
carSales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
# more plots
x = np.random.rand(10,4)
x

df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.982955  0.905371  0.582406  0.878252
# 1  0.648071  0.613830  0.330650  0.686463
# 2  0.801470  0.924558  0.326741  0.197404
# 3  0.350900  0.486309  0.444942  0.887395
# 4  0.401381  0.421417  0.023056  0.910558
# 5  0.735852  0.056439  0.961363  0.389016
# 6  0.372626  0.607148  0.471839  0.437950
# 7  0.888918  0.135851  0.938014  0.475411
# 8  0.367116  0.433142  0.968561  0.237271
# 9  0.739415  0.424573  0.227225  0.860977

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
carSales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
carSales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
carSales["Odometer (KM)"].plot.hist();

# %%
carSales["Odometer (KM)"].plot(kind="hist");

# %%
carSales["Odometer (KM)"].plot.hist(bins=100);

# %%
# testing on a new dataset
heartDisease = pd.read_csv("data/heart-disease.csv")
heartDisease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# create a histogram of age
heartDisease["age"].plot.hist();

# %%
heartDisease["age"].plot.hist(bins=20);

# %%
heartDisease["age"].plot.hist(bins=50);

# %%
heartDisease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heartDisease.plot.hist(figsize=(10,30), subplots=True);

# %%
heartDisease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over50 = heartDisease[heartDisease["age"]>50]
over50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
# pyplot method
over50.plot(kind='scatter', x='age',y='chol',c='target',figsize=(10,6));

# %%
# OO method mixed with pyplot
fig, ax = plt.subplots(figsize=(10,6))
over50.plot(kind='scatter', x='age',y='chol',c='target', ax=ax);

#ax.set_xlim([45, 100]); change x, limits

# %%
## OO method from scratch
fig, ax = plt.subplots(figsize=(10,6))

##plot the data
scatter = ax.scatter(x=over50["age"], y=over50["chol"], c=over50["target"]);

# customise the plot

ax.set(title="Heart Disease and Cholesterol Levels", xlabel="Age", ylabel="Cholesterol");

# add a legend

ax.legend(*scatter.legend_elements(), title="Target");

# add a horizontal line

ax.axhline(over50["chol"].mean(), linestyle="--");

# %%
over50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Sub plot of chol, thalach and age

fig, (ax0,ax1) = plt.subplots(nrows=2, ncols=1, figsize=(10,10), sharex = True);

# add data to ax0

scatter = ax0.scatter(x=over50["age"],y=over50["chol"],c=over50["target"]);

# customise the plot

ax0.set(title="Heart Disease and Cholesterol Levels", xlabel="Age", ylabel="Cholesterol");

# add a legend

ax0.legend(*scatter.legend_elements(), title="Target");

# add a horizontal line

ax0.axhline(over50["chol"].mean(), linestyle="--");

# add data to ax1

scatter = ax1.scatter(x=over50["age"],y=over50["thalach"],c=over50["target"]);

# customise the plot

ax1.set(title="Heart Disease and Max Heart Rate", xlabel="Age", ylabel="Max Heart Rate");

# add a legend

ax1.legend(*scatter.legend_elements(), title="Target");

# add a horizontal line

ax1.axhline(over50["thalach"].mean(), linestyle="--");

# add a title to the figure

fig.suptitle("Heart Disease Analysis", fontsize = 16, fontweight = "bold");

# %% [markdown]
# ## Customisig Matplotlib plots- Adding styles

# %%
# see the different styles available
plt.style.available
# Out:
# ['seaborn-paper',
#  'seaborn',
#  'fivethirtyeight',
#  'bmh',
#  'dark_background',
#  '_classic_test',
#  'seaborn-white',
#  'seaborn-ticks',
#  'seaborn-dark',
#  'classic',
#  'seaborn-colorblind',
#  'seaborn-notebook',
#  'seaborn-dark-palette',
#  'seaborn-whitegrid',
#  'seaborn-pastel',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-darkgrid',
#  'fast',
#  'seaborn-deep',
#  'ggplot',
#  'tableau-colorblind10',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-muted',
#  'Solarize_Light2']

# %%
carSales["Price"].plot(); # default style

# %%
plt.style.use('seaborn-whitegrid')
carSales["Price"].plot();

# %%
plt.style.use('seaborn')
carSales["Price"].plot();

# %%
plt.style.use('ggplot')
carSales["Price"].plot();

# %%
# Create some data
x = np.random.randn(10,4)
x
# Out:
# array([[-0.66610288,  0.31371373,  0.89270919, -2.23975283],
#        [-0.26192178, -1.06538258,  0.22931984, -0.46608253],
#        [-2.23275282, -1.2784469 , -0.17081534, -0.90793291],
#        [-1.11186993,  0.90123552,  0.15169281,  0.52685437],
#        [-1.1267011 ,  0.97739729, -0.67125166, -0.39794618],
#        [-0.28301525,  1.02703621,  2.39846522, -0.77993007],
#        [-1.04281155,  0.99778374, -3.31702312, -0.55460806],
#        [ 0.53706792,  1.15914913,  1.09715023, -0.63711251],
#        [-0.11237621,  0.35950899,  0.8619469 ,  1.1476509 ],
#        [-0.94391888, -0.79294685, -0.08058483, -2.21620859]])

# %%
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -0.666103  0.313714  0.892709 -2.239753
# 1 -0.261922 -1.065383  0.229320 -0.466083
# 2 -2.232753 -1.278447 -0.170815 -0.907933
# 3 -1.111870  0.901236  0.151693  0.526854
# 4 -1.126701  0.977397 -0.671252 -0.397946
# 5 -0.283015  1.027036  2.398465 -0.779930
# 6 -1.042812  0.997784 -3.317023 -0.554608
# 7  0.537068  1.159149  1.097150 -0.637113
# 8 -0.112376  0.359509  0.861947  1.147651
# 9 -0.943919 -0.792947 -0.080585 -2.216209

# %%
ax = df.plot(kind='bar');

# %%
# customising with set method
ax = df.plot(kind='bar')

ax.set(title="Random Graph", xlabel="Row Number", ylabel="Random Number");

# %%
# Styling from within set

plt.style.use('seaborn-whitegrid')

## OO method from scratch
fig, ax = plt.subplots(figsize=(10,6))

##plot the data
scatter = ax.scatter(x=over50["age"], y=over50["chol"], c=over50["target"], cmap="winter"); # changed color scheme with cmap

# customise the plot

ax.set(title="Heart Disease and Cholesterol Levels", xlabel="Age", ylabel="Cholesterol");

# add a legend

ax.legend(*scatter.legend_elements(), title="Target");

# add a horizontal line

ax.axhline(over50["chol"].mean(), linestyle="--");

# %%
# Customizing the x and y limitations

# Sub plot of chol, thalach and age

fig, (ax0,ax1) = plt.subplots(nrows=2, ncols=1, figsize=(10,10), sharex = True);

# add data to ax0

scatter = ax0.scatter(x=over50["age"],y=over50["chol"],c=over50["target"], cmap="winter");

# customise the plot

ax0.set(title="Heart Disease and Cholesterol Levels", xlabel="Age", ylabel="Cholesterol");

ax0.set_xlim([50,80])

# add a legend

ax0.legend(*scatter.legend_elements(), title="Target");

# add a horizontal line

ax0.axhline(over50["chol"].mean(), linestyle="--");

# add data to ax1

scatter = ax1.scatter(x=over50["age"],y=over50["thalach"],c=over50["target"], cmap="winter");

# customise the plot

ax1.set(title="Heart Disease and Max Heart Rate", xlabel="Age", ylabel="Max Heart Rate");

ax1.set_xlim([50,80])
ax1.set_ylim([60,200])

# add a legend

ax1.legend(*scatter.legend_elements(), title="Target");

# add a horizontal line

ax1.axhline(over50["thalach"].mean(), linestyle="--");

# add a title to the figure

fig.suptitle("Heart Disease Analysis", fontsize = 16, fontweight = "bold");

# %%
# Saving plots

fig.savefig("plots/heart-disease-analysis")
